# %%
import numpy as np
import pandas as pd

# %%
#read datasets
train_txn = pd.read_csv('final_txn.csv', index_col = 'new_id')
train_user = pd.read_csv('final_user_log.csv', index_col = 'new_id')
#train = train_txn.merge(train_user, how='inner')
train_txn.head()
# Out:
#          is_churn  in_txn  payment_plan_days  plan_list_price  \
# new_id
# 1025093         1    True                 37              149
# 476532          1    True                633             3160
# 731853          1    True                300             1492
# 854199          1    True                820             1788
# 601853          1    True                785             3576
#
#          actual_amount_paid  avg_daily_paid  list_actual_diff   mean_ar  \
# new_id
# 1025093                 149        4.027027                 0  0.000000
# 476532                 3309        5.227488             65387  0.954545
# 731853                 1492        4.973333                 0  0.800000
# 854199                 1788        2.180488                 0  0.000000
# 601853                 3576        4.555414                 0  0.000000
#
#          last_ar  stopped_ar  mean_cancel  cancelled  last_cancel  \
# new_id
# ...

# %%
train_txn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 990834 entries, 1025093 to 15788
# Data columns (total 20 columns):
# is_churn              990834 non-null int64
# in_txn                990834 non-null bool
# payment_plan_days     990834 non-null int64
# plan_list_price       990834 non-null int64
# actual_amount_paid    990834 non-null int64
# avg_daily_paid        990834 non-null float64
# list_actual_diff      990834 non-null int64
# mean_ar               990834 non-null float64
# last_ar               990834 non-null int64
# stopped_ar            990834 non-null bool
# mean_cancel           990834 non-null float64
# cancelled             990834 non-null bool
# last_cancel           990834 non-null int64
# last_plan_price       990834 non-null int64
# lst_free_trial        990834 non-null bool
# txn_cnt               990834 non-null int64
# lp_high_cnt           353688 non-null float64
# per_lp_high           353688 non-null float64
# ...

# %%
train_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 992931 entries, 1025093 to 639550
# Data columns (total 7 columns):
# is_churn            992931 non-null int64
# no_songs_cp6        869926 non-null float64
# months_listening    865735 non-null object
# listening_p6        869926 non-null float64
# listening_p12       869926 non-null float64
# logavg_secs_p12     869926 non-null float64
# freq_days           860066 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 60.6+ MB

# %%
'''
900,000 observations
54,000

15.6
'''

# %%
train_np = train.as_matrix()
oversample = train_np.repeat(train_np[train_np[:,0] == 1,:], 16)
